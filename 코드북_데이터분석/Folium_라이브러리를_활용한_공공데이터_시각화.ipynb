# %% [markdown]
# <a href="https://colab.research.google.com/github/kimmiso726/DataScience/blob/main/%EC%BD%94%EB%93%9C%EB%B6%81_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/Folium_%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 자전거 대여소 공공데이터 준비하기

# %%
# 1. pandas 선언
import pandas as pd

# 2. CSV 파일 불러오기
df=pd.read_csv('/content/세종특별자치시_공영자전거 어울링 대여소_20200915.csv', encoding='cp949')
df.head()
# Out:
#    STATION_ID STATION_NM  AREA  GU  ... ADDR2 LOCKER      Y_POS       X_POS
# 0           1    첫마을 1단지  1생활권  세종  ...   NaN     13  36.482114  127.259628
# 1           2    첫마을 3단지  1생활권  세종  ...   NaN     15  36.479850  127.260513
# 2           3   첫마을  4단지  1생활권  세종  ...   NaN     15  36.480436  127.253314
# 3           4   LH세종특별본부  2생활권  세종  ...   NaN     15  36.495484  127.266063
# 4           5   한솔동 주민센터  1생활권  세종  ...   NaN     14  36.478979  127.255524
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATION_ID  72 non-null     int64
#  1   STATION_NM  72 non-null     object
#  2   AREA        72 non-null     object
#  3   GU          72 non-null     object
#  4   DONG        72 non-null     object
#  5   ADDR1       72 non-null     object
#  6   ADDR2       0 non-null      float64
#  7   LOCKER      72 non-null     int64
#  8   Y_POS       72 non-null     float64
#  9   X_POS       72 non-null     float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 5.8+ KB

# %% [markdown]
# 지도에 표시할 대여소 정보 추출

# %%
df_route=df.loc[:,['STATION_NM', 'AREA','Y_POS', 'X_POS']]
df_route.head()
# Out:
#   STATION_NM  AREA      Y_POS       X_POS
# 0    첫마을 1단지  1생활권  36.482114  127.259628
# 1    첫마을 3단지  1생활권  36.479850  127.260513
# 2   첫마을  4단지  1생활권  36.480436  127.253314
# 3   LH세종특별본부  2생활권  36.495484  127.266063
# 4   한솔동 주민센터  1생활권  36.478979  127.255524

# %%
df_route.tail()
# Out:
#       STATION_NM  AREA      Y_POS       X_POS
# 67     홈플러스 조치원점  조치원읍  36.586800  127.297400
# 68      조치원역(서측)  조치원읍  36.602542  127.294760
# 69  공영버스터미널(조치원)  조치원읍  36.602002  127.302521
# 70  고려대학교(세종캠퍼스)  조치원읍  36.609900  127.293250
# 71  홍익대학교(세종캠퍼스)  조치원읍  36.620912  127.290678

# %% [markdown]
# 자전거 대여소 Marker 활용하여 지도 표출

# %%
# 지도에 표시하기 위해 folium 라이브러리
import folium

map = folium.Map(location=[df_route['Y_POS'].mean(), df_route['X_POS'].mean()],
                 zoom_start=11)

for n in df_route.index:
  if df_route.loc[n, 'AREA'] == '1생활권' :
    folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
                popup=df_route.loc[n, 'STATION_NM']+' '+df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='green', icon='fa-bicycle', prefix='fa')).add_to(map)
  elif df_route.loc[n, 'AREA'] == '2생활권' :
    folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
                popup=df_route.loc[n, 'STATION_NM']+' '+df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='blue', icon='fa-bicycle', prefix='fa')).add_to(map)
  elif df_route.loc[n, 'AREA'] == '3생활권' :
    folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
                popup=df_route.loc[n, 'STATION_NM']+' '+df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='pink', icon='fa-bicycle', prefix='fa')).add_to(map)
  elif df_route.loc[n, 'AREA'] == '4생활권' :
    folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
                popup=df_route.loc[n, 'STATION_NM']+' '+df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='orange', icon='fa-bicycle', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_6dff4a68348049e78afcfc108a03a450%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6dff4a68348049e78afcfc108a03a450%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_6dff4a68348049e78afcfc108a03a450%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_6dff4a68348049e78afcfc108a03a450%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_cbc43ef0894f4cc3aff70f29907ad207%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %%
# 지도에 표시하기 위해 folium 라이브러리
import folium
map = folium.Map(location=[df_route['Y_POS'].mean(), df_route['X_POS'].mean()],
                           zoom_start = 11)
c = ['green','blue','red','gray','pink','black']
for n in df_route.index:
    for i in range(0,5):
        if str(df_route.loc[n, 'AREA'][0]) == str(i+1):
            folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
            popup = df_route.loc[n, 'STATION_NM'] + ' ' + df_route.loc[n, 'AREA'],
            icon=folium.Icon(color=c[i], icon='fa-bicycle', prefix='fa')).add_to(map)
            break  
        else:
            folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
            popup = df_route.loc[n, 'STATION_NM'] + ' ' + df_route.loc[n, 'AREA'],
            icon=folium.Icon(color='orange', icon='fa-bicycle', prefix='fa')).add_to(map)
map

# 지도에 표시하기 위해 folium 라이브러리
import folium
map = folium.Map(location=[df_route['Y_POS'].mean(), df_route['X_POS'].mean()],
                           zoom_start = 11)
c = ['green','blue','red','gray']
for n in df_route.index:
    for i in range(0,4):
        if df_route.loc[n, 'AREA'][0] == str(i+1):
            folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
            popup = df_route.loc[n, 'STATION_NM'] + ' ' + df_route.loc[n, 'AREA'],
            icon=folium.Icon(color=c[i], icon='fa-bicycle', prefix='fa')).add_to(map)
            break  
        else:
            folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
            popup = df_route.loc[n, 'STATION_NM'] + ' ' + df_route.loc[n, 'AREA'],
            icon=folium.Icon(color='orange', icon='fa-bicycle', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_c0f95aa2a55846b9ad9057fd11af6674%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c0f95aa2a55846b9ad9057fd11af6674%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_c0f95aa2a55846b9ad9057fd11af6674%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_c0f95aa2a55846b9ad9057fd11af6674%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_1ec307d45b424b0f806f7a29bbf1695b%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# # 가로등 설치 공공데이터 준비하기

# %%
lamp_df = pd.read_csv('/content/세종특별자치시_가로등정보_20190919..csv', encoding='cp949')
lamp_df.head()
# Out:
#               가로등위치명  설치대수 소재지도로명주소  ...      관리기관전화번호     관리기관명     데이터기준일자
# 0      전동면 노장리 609-9     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 1  세종특별자치시 대평동 574-2     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 2      전동면 노장리 609-9     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 3  세종특별자치시 대평동 574-2     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 4      연기면 산울리 141-3     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
#
# [5 rows x 11 columns]

# %% [markdown]
# 지도에 표시할 가로등 정보 추출

# %%
lamp_route=lamp_df.loc[:, ['가로등위치명', '위도', '경도']]
lamp_route.head()
# Out:
#               가로등위치명         위도          경도
# 0      전동면 노장리 609-9  36.652672  127.268525
# 1  세종특별자치시 대평동 574-2  36.469947  127.269149
# 2      전동면 노장리 609-9  36.654752  127.268148
# 3  세종특별자치시 대평동 574-2  36.469487  127.268955
# 4      연기면 산울리 141-3  36.529309  127.264695

# %% [markdown]
# 가로등 Marker 활용하여 지도 표출

# %%
# 가로등 정도 100건만 사용하여 지도 표출

for n in lamp_route.index[:100]:
  folium.Marker([lamp_route.loc[n, '위도'], lamp_route.loc[n, '경도']], # 위도, 경도
              popup=lamp_route.loc[n, '가로등위치명'],
              icon=folium.Icon(color='orange', icon='lightbulb-o', prefix='fa')).add_to(map)
map

# %% [markdown]
# #CCTV 데이터 올리기

# %%
cctv_df=pd.read_csv('/content/세종특별자치시_CCTV_20210101.csv', encoding='cp949')
cctv_df.head()
# Out:
#      관리기관명             소재지도로명주소  ...          경도     데이터기준일자
# 0  세종특별자치시  세종특별자치시 조치원읍 건강길 16  ...  127.296286  2021-01-01
# 1  세종특별자치시                  NaN  ...  127.302452  2021-01-01
# 2  세종특별자치시                  NaN  ...  127.300492  2021-01-01
# 3  세종특별자치시                  NaN  ...  127.301301  2021-01-01
# 4  세종특별자치시                  NaN  ...  127.303145  2021-01-01
#
# [5 rows x 12 columns]

# %%
for n in lamp_route.index[:100]:
  folium.Marker([lamp_route.loc[n, '위도'],
                 lamp_route.loc[n, '경도']], # 위도, 경도
                icon=folium.Icon(icon='video-camera', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_c0f95aa2a55846b9ad9057fd11af6674%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c0f95aa2a55846b9ad9057fd11af6674%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_c0f95aa2a55846b9ad9057fd11af6674%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_c0f95aa2a55846b9ad9057fd11af6674%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_1ec307d45b424b0f806f7a29bbf1695b%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...
